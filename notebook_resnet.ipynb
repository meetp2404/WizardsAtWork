# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/stanford-car-dataset-by-classes-folder/names.csv
# /kaggle/input/stanford-car-dataset-by-classes-folder/anno_test.csv
# /kaggle/input/stanford-car-dataset-by-classes-folder/anno_train.csv
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/04772.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/08033.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/03004.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06551.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/01397.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06801.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/00641.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/00455.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06977.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/00407.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06270.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/02822.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06375.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/03575.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/03997.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/07155.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06672.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/05238.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/07598.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/02633.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/05674.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06326.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/03632.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/00501.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/02753.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/01101.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/04167.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/07032.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/02023.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06303.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/03316.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/00131.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/01446.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/00404.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06769.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/03576.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/05330.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/06127.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/03352.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/07231.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/03767.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Dodge Ram Pickup 3500 Crew Cab 2010/07536.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/00091.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/02184.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/00617.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/02957.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/07017.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/00073.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/03498.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/02770.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/07445.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/01588.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/04531.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/07573.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/06657.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/03733.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/05636.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/03082.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/01844.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/03122.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/05380.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/05155.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/02193.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/05828.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/01079.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/06412.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/02348.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/07362.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/03376.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/05526.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/06455.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/00016.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/00283.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/03631.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/05117.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/01082.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/07252.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/01174.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/05704.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/00233.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/05958.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/01303.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/00915.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/00556.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Cadillac CTS-V Sedan 2012/05262.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/01001.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/06024.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/06568.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/05148.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/06631.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/04082.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/05634.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/06188.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/04478.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/06293.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/01321.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/07310.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/03690.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/01965.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/05494.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/02302.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/05612.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/02901.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/03598.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/02619.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/04974.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/07346.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/07473.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/03283.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/04133.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/07420.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/05875.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/02739.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/03035.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/04165.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/06439.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/04842.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/02669.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/00674.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/00102.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/05554.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/00362.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/06347.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/00709.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/07561.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/05982.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi S5 Convertible 2012/06735.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/00706.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/02085.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/03729.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/00081.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/03402.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/06625.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/07212.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/00475.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/06828.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/00753.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/07563.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/06044.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/04727.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/00959.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/00654.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/07117.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/02059.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/02853.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/06287.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/02566.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/02010.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/00080.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/03743.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/06394.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/04873.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/00124.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/03342.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/00865.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/07099.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/05359.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/04520.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/03564.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/04355.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/02406.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/05718.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/01279.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/07190.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/02975.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/03635.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/03799.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Ram C-V Cargo Van Minivan 2012/01472.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/00583.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/02007.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/04490.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/02493.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/05789.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/01246.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/03908.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/03742.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/03483.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/06479.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/03157.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/05728.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/05966.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/07592.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/07236.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/02985.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/06886.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/00718.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/05236.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/00933.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/06028.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/03397.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/01712.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/01112.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/04307.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/03590.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/04189.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/00764.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/01736.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/03711.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/06615.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/01778.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/05706.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/07467.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/01293.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/01238.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/00622.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/05723.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/04973.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/smart fortwo Convertible 2012/05253.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/01093.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/04006.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/04029.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07043.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07700.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07430.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/03945.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/05838.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/06335.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07681.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/00810.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07224.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/01649.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07979.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/02707.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/08038.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07646.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/04206.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/01820.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/03189.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/02862.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/06032.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/02497.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/04923.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/06912.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/04858.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/05214.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/02976.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/02005.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/04562.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/01583.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07650.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/03443.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07902.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/03331.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07915.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/06245.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/06911.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/04657.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/01858.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/04316.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/06770.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Audi V8 Sedan 1994/07943.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03470.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03423.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/00247.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/01937.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/07821.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/05007.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03284.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/01231.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03450.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03991.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/07923.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/04291.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03381.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/02826.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/06021.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/06685.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/02290.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03931.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/00208.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/05945.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/06967.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/02958.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/08010.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03359.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03989.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/06016.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/05409.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/05207.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/02065.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/00736.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/01682.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/01997.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/01516.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/02512.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03165.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/06756.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/01005.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/01792.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/05331.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/00771.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/03081.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/05529.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/02841.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/02922.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/05434.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Suzuki Kizashi Sedan 2012/06206.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/06572.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/07894.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/07737.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/00324.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/01678.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/07325.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/06525.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/00252.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/02257.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/04049.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/03054.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/02722.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/02969.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/01993.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/00150.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/05386.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/06586.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/03515.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/03701.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/04813.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/04131.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/07335.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/03745.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/04008.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/03993.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/01434.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/06231.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/01427.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/05097.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/00552.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/04900.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/03827.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/04937.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/00168.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chevrolet Express Van 2007/06999.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/05821.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02775.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/00872.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/01611.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/00984.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/05845.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/05088.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/01819.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/07586.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/05995.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/01866.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/00006.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02388.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02299.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/05588.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/01870.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/06744.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02674.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02749.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/00355.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/03431.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02986.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/05731.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/04019.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02697.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02293.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/07376.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/01009.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02842.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/05583.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/02913.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/04761.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/07806.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/04655.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/01552.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/00986.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Chrysler Town and Country Minivan 2012/05983.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/03037.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/04218.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/07074.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/03714.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01550.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/02662.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01942.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/00431.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01985.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/07721.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/05575.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06881.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/03412.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06149.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06221.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06559.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/05849.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01345.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/07484.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06376.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01988.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01023.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06612.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06837.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/00975.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/02370.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/04186.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06515.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01889.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06155.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/07360.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/07377.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06103.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01157.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/05287.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01511.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06254.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01370.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06133.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/02295.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/07676.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/05473.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/06236.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Rolls-Royce Phantom Sedan 2012/01412.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Buick Regal GS 2012/01215.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Buick Regal GS 2012/06623.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/test/Buick Regal GS 2012/05510.jpg
# ...
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/06026.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/00932.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/00607.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/01342.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/01328.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/07850.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/04761.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/02458.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/03006.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/01360.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/04280.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/05191.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Camaro Convertible 2012/05983.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/01306.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/02817.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/04039.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/03369.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/05230.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/03043.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/05133.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/04301.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/01187.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/02777.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/02799.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/04099.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/07835.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/02902.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/04867.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/04781.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/06046.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/04745.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/07365.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/05560.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/05204.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/07941.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/07100.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/01633.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/01350.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/04674.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/06198.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/07717.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/06085.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/01749.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/05505.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/05652.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/04935.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/00633.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/03016.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/03713.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/MINI Cooper Roadster Convertible 2012/07959.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/08063.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/00109.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/04188.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/04518.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/02399.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01849.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/04222.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/00453.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/06642.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01376.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01856.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/02700.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/08059.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/06336.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/07786.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01143.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01626.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/03189.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/05025.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/07415.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/07266.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01635.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/00575.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/07738.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/00807.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/05901.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/06853.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/03375.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/00301.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/00528.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/04024.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/00225.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01583.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/04324.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/05943.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/06749.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/07794.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/00491.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/03348.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/02361.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/03134.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01145.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/03491.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01601.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/GMC Acadia SUV 2012/01220.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/05437.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/03737.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/05013.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/02990.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00968.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/05338.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/06780.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/05274.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00769.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00745.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/05833.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00965.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/04267.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/02140.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/02744.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/01062.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/06807.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/02517.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/02909.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00654.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/06693.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/02436.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/06618.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00245.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/03918.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/04589.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00282.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00492.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00103.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00529.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/01033.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/03597.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/02804.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/02575.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/04440.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/05179.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00831.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00227.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/03217.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/03831.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00676.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/00661.jpg
# /kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/train/Chevrolet Impala Sedan 2007/04201.jpg

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.models as models
from PIL import Image
import json
from matplotlib.ticker import FormatStrFormatter
import os

# %%
data_dir = '/kaggle/input/stanford-car-dataset-by-classes-folder/car_data/car_data/'
train_dir = data_dir + '/train'
test_dir = data_dir + '/test'

# %%
train_transforms = transforms.Compose([transforms.Resize((244,244)),
                                       transforms.RandomRotation(30),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])


# The validation set will use the same transform as the test set
test_transforms = transforms.Compose([transforms.Resize((244,244)),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# Load the datasets with ImageFolder
train_data = datasets.ImageFolder(data_dir + '/train', transform=train_transforms)
test_data = datasets.ImageFolder(data_dir + '/test', transform=test_transforms)

# Using the image datasets and the trainforms, define the dataloaders
# The trainloader will have shuffle=True so that the order of the images do not affect the model
trainloader = torch.utils.data.DataLoader(train_data, batch_size=128, shuffle=True)
testloader = torch.utils.data.DataLoader(test_data, batch_size=32, shuffle=True)

# %%
train_data

# %%
#model = models.densenet121(pretrained=True)
model = models.resnet34(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %%
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 196)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
lrscheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=3, threshold = 0.9)

# %%
# Implement a function for the validation pass
def validation(model, validloader, criterion):
    valid_loss = 0
    accuracy = 0
    
    # change model to work with cuda
    model.to('cuda')

    # Iterate over data from validloader
    for ii, (images, labels) in enumerate(validloader):
    
        # Change images and labels to work with cuda
        images, labels = images.to('cuda'), labels.to('cuda')

        # Forward pass image though model for prediction
        output = model.forward(images)
        # Calculate loss
        valid_loss += criterion(output, labels).item()
        # Calculate probability
        ps = torch.exp(output)
        
        # Calculate accuracy
        equality = (labels.data == ps.max(dim=1)[1])
        accuracy += equality.type(torch.FloatTensor).mean()
    
    return valid_loss, accuracy

# %%
epochs = 10
steps = 0
print_every = 40

# change to gpu mode
model.to('cuda')
model.train()
for e in range(epochs):

    running_loss = 0
    
    # Iterating over data to carry out training step
    for ii, (inputs, labels) in enumerate(trainloader):
        steps += 1
        
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        
        # zeroing parameter gradients
        optimizer.zero_grad()
        
        # Forward and backward passes
        outputs = model.forward(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        # Carrying out validation step
        if steps % print_every == 0:
            # setting model to evaluation mode during validation
            model.eval()
            
            # Gradients are turned off as no longer in training
            with torch.no_grad():
                valid_loss, accuracy = validation(model, testloader, criterion)
            
            print(f"No. epochs: {e+1}, \
            Training Loss: {round(running_loss/print_every,3)} \
            Valid Loss: {round(valid_loss/len(testloader),3)} \
            Valid Accuracy: {round(float(accuracy/len(testloader)),3)}")
            
            
            # Turning training back on
            model.train()
            lrscheduler.step(accuracy * 100)
# Out:
# No. epochs: 1,             Training Loss: 3.655             Valid Loss: 3.107             Valid Accuracy: 0.277
# No. epochs: 2,             Training Loss: 0.956             Valid Loss: 2.373             Valid Accuracy: 0.429
# No. epochs: 2,             Training Loss: 2.972             Valid Loss: 1.951             Valid Accuracy: 0.492
# No. epochs: 3,             Training Loss: 1.111             Valid Loss: 1.537             Valid Accuracy: 0.585
# No. epochs: 4,             Training Loss: 0.182             Valid Loss: 1.539             Valid Accuracy: 0.577
# No. epochs: 4,             Training Loss: 1.044             Valid Loss: 1.176             Valid Accuracy: 0.667
# No. epochs: 5,             Training Loss: 0.353             Valid Loss: 1.02             Valid Accuracy: 0.713
# No. epochs: 5,             Training Loss: 0.922             Valid Loss: 1.175             Valid Accuracy: 0.674
# No. epochs: 6,             Training Loss: 0.393             Valid Loss: 0.733             Valid Accuracy: 0.797
# No. epochs: 7,             Training Loss: 0.122             Valid Loss: 0.707             Valid Accuracy: 0.803
# No. epochs: 7,             Training Loss: 0.437             Valid Loss: 0.699             Valid Accuracy: 0.805
# No. epochs: 8,             Training Loss: 0.228             Valid Loss: 0.687             Valid Accuracy: 0.809
# No. epochs: 9,             Training Loss: 0.059             Valid Loss: 0.686             Valid Accuracy: 0.809
# No. epochs: 9,             Training Loss: 0.334             Valid Loss: 0.683             Valid Accuracy: 0.81
# No. epochs: 10,             Training Loss: 0.167             Valid Loss: 0.682             Valid Accuracy: 0.81
# No. epochs: 10,             Training Loss: 0.449             Valid Loss: 0.683             Valid Accuracy: 0.81

# %%
correct = 0
total = 0
model.to('cuda')


with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to('cuda'), labels.to('cuda')
        # Get probabilities
        outputs = model(images)
        # Turn probabilities into predictions
        _, predicted_outcome = torch.max(outputs.data, 1)
        # Total number of images
        total += labels.size(0)
        # Count number of cases in which predictions are correct
        correct += (predicted_outcome == labels).sum().item()

print(f"Test accuracy of model: {round(100 * correct / total,3)}%")
# Out:
# Test accuracy of model: 77.366%

# %%
# Saving: feature weights, new model.fc, index-to-class mapping, optimiser state, and No. of epochs
checkpoint = {'state_dict': model.state_dict(),
              'model': model.fc,
              'class_to_idx': train_data.class_to_idx,
              'opt_state': optimizer.state_dict,
              'num_epochs': epochs}

torch.save(checkpoint, 'my_checkpoint1.pth')

# %%
# Write a function that loads a checkpoint and rebuilds the model

def load_checkpoint(filepath):

    checkpoint = torch.load(filepath)
    
    #model.load_state_dict(checkpoint['state_dict'])
    model.load_state_dict(checkpoint['state_dict'], strict=False)
    model.class_to_idx = checkpoint['class_to_idx']
    
    return model

# %%
# Loading model
model = load_checkpoint('my_checkpoint1.pth')
# Checking model i.e. should have 196 output units in the classifier
print(model)
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=196, bias=True)
#   )
# )

# %%
torch.save(model.module, 'resnet_final.pt')

# %%
model = torch.nn.DataParallel(model)

# %%
def process_image(image):
    
    # Process a PIL image for use in a PyTorch model

    # Converting image to PIL image using image file path
    pil_im = Image.open(f'{image}' + '.jpg')

    # Building image transform
    transform = transforms.Compose([transforms.Resize((244,244)),
                                    #transforms.CenterCrop(224),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406], 
                                                         [0.229, 0.224, 0.225])]) 
    
    # Transforming image for use with network
    pil_tfd = transform(pil_im)
    
    # Converting to Numpy array 
    array_im_tfd = np.array(pil_tfd)
    
    return array_im_tfd

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
imshow(process_image(data_dir + 'test/Audi S4 Sedan 2012/00133'))
# Out:
# <AxesSubplot:>

# %%
def predict(image_path, model, topk=5):
    # Implement the code to predict the class from an image file   
    
    # Loading model - using .cpu() for working with CPUs
    loaded_model = load_checkpoint(model)
    # Pre-processing image
    img = process_image(image_path)
    # Converting to torch tensor from Numpy array
    img_tensor = torch.from_numpy(img).type(torch.FloatTensor)
    # Adding dimension to image to comply with (B x C x W x H) input of model
    img_add_dim = img_tensor.unsqueeze_(0)

    # Setting model to evaluation mode and turning off gradients
    loaded_model.eval()
    with torch.no_grad():
        # Running image through network
        output = loaded_model.forward(img_add_dim)
        
    #conf, predicted = torch.max(output.data, 1)   
    probs_top = output.topk(topk)[0]
    predicted_top = output.topk(topk)[1]
    
    # Converting probabilities and outputs to lists
    conf = np.array(probs_top)[0]
    predicted = np.array(predicted_top)[0]
        
    #return probs_top_list, index_top_list
    return conf, predicted

# %%
# tie the class indices to their names

def find_classes(dir):
    classes = os.listdir(dir)
    classes.sort()
    class_to_idx = {classes[i]: i for i in range(len(classes))}
    return classes, class_to_idx
classes, c_to_idx = find_classes(data_dir+"train")

print(classes, c_to_idx)
# Out:
# ['AM General Hummer SUV 2000', 'Acura Integra Type R 2001', 'Acura RL Sedan 2012', 'Acura TL Sedan 2012', 'Acura TL Type-S 2008', 'Acura TSX Sedan 2012', 'Acura ZDX Hatchback 2012', 'Aston Martin V8 Vantage Convertible 2012', 'Aston Martin V8 Vantage Coupe 2012', 'Aston Martin Virage Convertible 2012', 'Aston Martin Virage Coupe 2012', 'Audi 100 Sedan 1994', 'Audi 100 Wagon 1994', 'Audi A5 Coupe 2012', 'Audi R8 Coupe 2012', 'Audi RS 4 Convertible 2008', 'Audi S4 Sedan 2007', 'Audi S4 Sedan 2012', 'Audi S5 Convertible 2012', 'Audi S5 Coupe 2012', 'Audi S6 Sedan 2011', 'Audi TT Hatchback 2011', 'Audi TT RS Coupe 2012', 'Audi TTS Coupe 2012', 'Audi V8 Sedan 1994', 'BMW 1 Series Convertible 2012', 'BMW 1 Series Coupe 2012', 'BMW 3 Series Sedan 2012', 'BMW 3 Series Wagon 2012', 'BMW 6 Series Convertible 2007', 'BMW ActiveHybrid 5 Sedan 2012', 'BMW M3 Coupe 2012', 'BMW M5 Sedan 2010', 'BMW M6 Convertible 2010', 'BMW X3 SUV 2012', 'BMW X5 SUV 2007', 'BMW X6 SUV 2012', 'BMW Z4 Convertible 2012', 'Bentley Arnage Sedan 2009', 'Bentley Continental Flying Spur Sedan 2007', 'Bentley Continental GT Coupe 2007', 'Bentley Continental GT Coupe 2012', 'Bentley Continental Supersports Conv. Convertible 2012', 'Bentley Mulsanne Sedan 2011', 'Bugatti Veyron 16.4 Convertible 2009', 'Bugatti Veyron 16.4 Coupe 2009', 'Buick Enclave SUV 2012', 'Buick Rainier SUV 2007', 'Buick Regal GS 2012', 'Buick Verano Sedan 2012', 'Cadillac CTS-V Sedan 2012', 'Cadillac Escalade EXT Crew Cab 2007', 'Cadillac SRX SUV 2012', 'Chevrolet Avalanche Crew Cab 2012', 'Chevrolet Camaro Convertible 2012', 'Chevrolet Cobalt SS 2010', 'Chevrolet Corvette Convertible 2012', 'Chevrolet Corvette Ron Fellows Edition Z06 2007', 'Chevrolet Corvette ZR1 2012', 'Chevrolet Express Cargo Van 2007', 'Chevrolet Express Van 2007', 'Chevrolet HHR SS 2010', 'Chevrolet Impala Sedan 2007', 'Chevrolet Malibu Hybrid Sedan 2010', 'Chevrolet Malibu Sedan 2007', 'Chevrolet Monte Carlo Coupe 2007', 'Chevrolet Silverado 1500 Classic Extended Cab 2007', 'Chevrolet Silverado 1500 Extended Cab 2012', 'Chevrolet Silverado 1500 Hybrid Crew Cab 2012', 'Chevrolet Silverado 1500 Regular Cab 2012', 'Chevrolet Silverado 2500HD Regular Cab 2012', 'Chevrolet Sonic Sedan 2012', 'Chevrolet Tahoe Hybrid SUV 2012', 'Chevrolet TrailBlazer SS 2009', 'Chevrolet Traverse SUV 2012', 'Chrysler 300 SRT-8 2010', 'Chrysler Aspen SUV 2009', 'Chrysler Crossfire Convertible 2008', 'Chrysler PT Cruiser Convertible 2008', 'Chrysler Sebring Convertible 2010', 'Chrysler Town and Country Minivan 2012', 'Daewoo Nubira Wagon 2002', 'Dodge Caliber Wagon 2007', 'Dodge Caliber Wagon 2012', 'Dodge Caravan Minivan 1997', 'Dodge Challenger SRT8 2011', 'Dodge Charger SRT-8 2009', 'Dodge Charger Sedan 2012', 'Dodge Dakota Club Cab 2007', 'Dodge Dakota Crew Cab 2010', 'Dodge Durango SUV 2007', 'Dodge Durango SUV 2012', 'Dodge Journey SUV 2012', 'Dodge Magnum Wagon 2008', 'Dodge Ram Pickup 3500 Crew Cab 2010', 'Dodge Ram Pickup 3500 Quad Cab 2009', 'Dodge Sprinter Cargo Van 2009', 'Eagle Talon Hatchback 1998', 'FIAT 500 Abarth 2012', 'FIAT 500 Convertible 2012', 'Ferrari 458 Italia Convertible 2012', 'Ferrari 458 Italia Coupe 2012', 'Ferrari California Convertible 2012', 'Ferrari FF Coupe 2012', 'Fisker Karma Sedan 2012', 'Ford E-Series Wagon Van 2012', 'Ford Edge SUV 2012', 'Ford Expedition EL SUV 2009', 'Ford F-150 Regular Cab 2007', 'Ford F-150 Regular Cab 2012', 'Ford F-450 Super Duty Crew Cab 2012', 'Ford Fiesta Sedan 2012', 'Ford Focus Sedan 2007', 'Ford Freestar Minivan 2007', 'Ford GT Coupe 2006', 'Ford Mustang Convertible 2007', 'Ford Ranger SuperCab 2011', 'GMC Acadia SUV 2012', 'GMC Canyon Extended Cab 2012', 'GMC Savana Van 2012', 'GMC Terrain SUV 2012', 'GMC Yukon Hybrid SUV 2012', 'Geo Metro Convertible 1993', 'HUMMER H2 SUT Crew Cab 2009', 'HUMMER H3T Crew Cab 2010', 'Honda Accord Coupe 2012', 'Honda Accord Sedan 2012', 'Honda Odyssey Minivan 2007', 'Honda Odyssey Minivan 2012', 'Hyundai Accent Sedan 2012', 'Hyundai Azera Sedan 2 ...

# %%
model_path = 'my_checkpoint1.pth'
image_path = data_dir + 'test/Audi S4 Sedan 2012/00133'


conf1, predicted1 = predict(image_path, model_path, topk=5)

print(conf1)
print(classes[predicted1[0]])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_23/1128560772.py in <module>
#       3
#       4
# ----> 5 conf1, predicted1 = predict(image_path, model_path, topk=5)
#       6
#       7 print(conf1)
#
# /tmp/ipykernel_23/3032356120.py in predict(image_path, model, topk)
#      15     with torch.no_grad():
#      16         # Running image through network
# ---> 17         output = loaded_model.forward(img_add_dim)
#      18
#      19     #conf, predicted = torch.max(output.data, 1)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     154                     raise RuntimeError("module must have its parameters and buffers "
#     155                                        "on device {} (device_ids[0]) but found one of "
# --> 156                                        "them on device: {}".format(self.src_device_obj, t.device))
#     157
#     158             inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#
# RuntimeError: module must have its parameters and buffers on device cuda:0 (device_ids[0]) but found one of them on device: cpu

# %%
model.eval()
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=196, bias=True)
#   )
# )

# %%
model.save('resnet.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_23/2282960073.py in <module>
# ----> 1 model.save('resnet.h5')
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1184                 return modules[name]
#    1185         raise AttributeError("'{}' object has no attribute '{}'".format(
# -> 1186             type(self).__name__, name))
#    1187
#    1188     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# AttributeError: 'DataParallel' object has no attribute 'save'
